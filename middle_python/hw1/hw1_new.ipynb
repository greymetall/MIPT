# %% [markdown]
# ### Задание 1

# %%
import pandas as pd
import zipfile
import json
import sqlite3
from pathlib import Path

# %%
# Читаем файл json и сохраняем в DataFrame
okved_df = pd.read_json('okved_2.json.zip')

# %%
okved_df
# Out:
#           code parent_code section  \
# 0           01           A       A
# 1         01.1          01       A
# 2        01.11        01.1       A
# 3      01.11.1       01.11       A
# 4     01.11.11     01.11.1       A
# ...        ...         ...     ...
# 2813         Q                   Q
# 2814         R                   R
# 2815         S                   S
# 2816         T                   T
# 2817         U                   U
#
#                                                    name  \
# 0     Растениеводство и животноводство, охота и пред...
# 1                        Выращивание однолетних культур
# 2     Выращивание зерновых (кроме риса), зернобобовы...
# 3                          Выращивание зерновых культур
# 4                                   Выращивание пшеницы
# ...                                                 ...
# 2813  ДЕЯТЕЛЬНОСТЬ В ОБЛАСТИ ЗДРАВООХРАНЕНИЯ И СОЦИА...
# 2814  ДЕЯТЕЛЬНОСТЬ В ОБЛАСТИ КУЛЬТУРЫ, СПОРТА, ОРГАН...
# 2815                  ПРЕДОСТАВЛЕНИЕ ПРОЧИХ ВИДОВ УСЛУГ
# 2816  ДЕЯТЕЛЬНОСТЬ ДОМАШНИХ ХОЗЯЙСТВ КАК РАБОТОДАТЕЛ...
# 2817  ДЕЯТЕЛЬНОСТЬ ЭКСТЕРРИТОРИАЛЬНЫХ ОРГАНИЗАЦИЙ И ...
#
#                                                 comment
# 0     Эта группировка включает:\n- два основных вида...
# 1     Эта группировка включает:\n- выращивание однол...
# 2     Эта группировка включает:\n- все формы выращив...
# 3
# 4
# ...                                                 ...
# 2813  Этот раздел включает:\n- предоставление деятел...
# 2814  Данный раздел включает:\n- широкий спектр видо...
# 2815  Этот раздел включает:\n- деятельность обществе...
# 2816
# 2817
#
# [2818 rows x 5 columns]

# %%
okved_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2818 entries, 0 to 2817
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         2818 non-null   object
#  1   parent_code  2818 non-null   object
#  2   section      2818 non-null   object
#  3   name         2818 non-null   object
#  4   comment      2818 non-null   object
# dtypes: object(5)
# memory usage: 110.2+ KB

# %%
# Создаём БД hw1.db и таблицу okved в ней
create_stmt = \
"""
create table if not exists okved(
    code text,
    parent_code text,
    section text,
    name text,
    comment text
)
"""
with sqlite3.connect('hw1.db') as connection:
    cursor = connection.cursor()
    try:
        cursor.execute(create_stmt)
    except(Exception) as error:
        print(error)
        connection.rollback()
    else:
        connection.commit()
    finally:
        cursor.close()

# %%
# Записываем данные из DataFrame в БД
with sqlite3.connect('hw1.db') as connection:
    okved_df.to_sql('okved', connection, if_exists='append', index=False, method='multi')

# %%
# Проверяем получившийся результат
with sqlite3.connect('hw1.db') as connection:
    df = pd.read_sql('select * from okved', connection)

display(df)
# Out:
#           code parent_code section  \
# 0           01           A       A
# 1         01.1          01       A
# 2        01.11        01.1       A
# 3      01.11.1       01.11       A
# 4     01.11.11     01.11.1       A
# ...        ...         ...     ...
# 2813         Q                   Q
# 2814         R                   R
# 2815         S                   S
# 2816         T                   T
# 2817         U                   U
#
#                                                    name  \
# 0     Растениеводство и животноводство, охота и пред...
# 1                        Выращивание однолетних культур
# 2     Выращивание зерновых (кроме риса), зернобобовы...
# 3                          Выращивание зерновых культур
# 4                                   Выращивание пшеницы
# ...                                                 ...
# 2813  ДЕЯТЕЛЬНОСТЬ В ОБЛАСТИ ЗДРАВООХРАНЕНИЯ И СОЦИА...
# 2814  ДЕЯТЕЛЬНОСТЬ В ОБЛАСТИ КУЛЬТУРЫ, СПОРТА, ОРГАН...
# 2815                  ПРЕДОСТАВЛЕНИЕ ПРОЧИХ ВИДОВ УСЛУГ
# 2816  ДЕЯТЕЛЬНОСТЬ ДОМАШНИХ ХОЗЯЙСТВ КАК РАБОТОДАТЕЛ...
# 2817  ДЕЯТЕЛЬНОСТЬ ЭКСТЕРРИТОРИАЛЬНЫХ ОРГАНИЗАЦИЙ И ...
#
#                                                 comment
# 0     Эта группировка включает:\n- два основных вида...
# 1     Эта группировка включает:\n- выращивание однол...
# 2     Эта группировка включает:\n- все формы выращив...
# 3
# 4
# ...                                                 ...
# 2813  Этот раздел включает:\n- предоставление деятел...
# 2814  Данный раздел включает:\n- широкий спектр видо...
# 2815  Этот раздел включает:\n- деятельность обществе...
# 2816
# 2817
#
# [2818 rows x 5 columns]

# %%
df[df.name.str.lower() == 'деятельность в сфере телекоммуникаций']
# Out:
#      code parent_code section                                   name  \
# 2193   61           J       J  Деятельность в сфере телекоммуникаций
#
#                                                 comment
# 2193  Эта группировка включает:\n- деятельность по п...

# %% [markdown]
# ### Задание 2

# %%
import pandas as pd
import zipfile
import sqlite3
from pathlib import Path
from tqdm import tqdm
from tqdm.notebook import tqdm_notebook
from multiprocessing.pool import ThreadPool as Pool
from concurrent.futures import ThreadPoolExecutor, as_completed
import os

# %%
from concurrent.futures import wait
from typing import Tuple
from zipfile import ZipFile


file_path = Path('C:', 'Users', 'greym', 'Downloads', 'hw1', 'egrul.json.zip')
NPROC = os.cpu_count() - 1  # количество процессоров
MAX_WORKERS = max(1, round(os.cpu_count() / 2))  # количество потоков


def unpacker(path: 'str | Path') -> pd.DataFrame:
    """Распаковщик данных из zip-архива и парсер JSON"""

    def parser_json(zipobj: ZipFile, json_file: str) -> Tuple[str, pd.DataFrame]:
        """Парсит один файл JSON"""
        with zipobj.open(json_file) as file:
            return (json_file, pd.read_json(file))

    with zipfile.ZipFile(path, 'r') as zipobj:
        files = zipobj.infolist()
        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            # загружаем и отмечаем каждый будущий результат своим файлом
            counter = 0
            while files:
                futures = []
                file_lasts = len(files)
                for i in range(MAX_WORKERS):
                    if i < file_lasts:
                        futures.append(executor.submit(parser_json, zipobj, files[i].filename))

                files = files[MAX_WORKERS:]

                success_futures, _ = wait(futures)
                for future in success_futures:
                    filename, df = future.result()
                    counter += 1
                    print(f"File {filename} loaded ({counter})")
                    yield df


def parser_data(value: dict) -> dict:
    """Парсер атрибута data"""
    # Получаем значения КодОКВЭД и НаимОКВЭД. Если нет, устанавливаем значения в None
    main_val = dict(code_okved=value.get('СвОКВЭД', {}).get('СвОКВЭДОсн', {}).get('КодОКВЭД', None),
                    name_okved=value.get('СвОКВЭД', {}).get('СвОКВЭДОсн', {}).get('НаимОКВЭД', None),
                    type_okved='Осн')
    # add_val = value.get('СвОКВЭД', {}).get('СвОКВЭДДоп', def_dct)
    # if not isinstance(add_val, list):
    #    add_val = [add_val]
    # Фильтруем по 61 ОКВЭД
    code = main_val['code_okved']
    return main_val if code and code.startswith('61') else None


def processor_df(df: pd.DataFrame) -> pd.DataFrame:
    """Парсер и обработчик данных"""
    # Парсим атрибут data и записываем данные в общий DF
    df = df.assign(data=df.data.apply(parser_data))
    # Исключаем пустые данные (т.е. те, что не попали под ОКВЭД 61)
    df = df[df.data.notna()]
    # Разбиваем атрибут data на столбцы, и добавляем их в общий DF
    cols = ['ogrn', 'inn', 'kpp', 'name', 'full_name']
    return df[cols].join(df.data.apply(pd.Series))


# Создаём генератор-парсер данных из .zip архива в формате JSON
gen_dfs = unpacker(file_path)

# %%
# Парсим данные из JSON файлов в DF в параллельном режиме
with Pool(processes=NPROC) as process_pool:
    dfs = process_pool.map(processor_df, gen_dfs, chunksize=NPROC)
# Out:
# File 06439.json loaded (1)
# File 04669.json loaded (2)
# File 03534.json loaded (3)
# File 00393.json loaded (4)
# File 10339.json loaded (5)
# File 07388.json loaded (6)
# File 09162.json loaded (7)
# File 05575.json loaded (8)
# File 08312.json loaded (9)
# File 06849.json loaded (10)
# File 05296.json loaded (11)
# File 08667.json loaded (12)
# File 10549.json loaded (13)
# File 10851.json loaded (14)
# File 03216.json loaded (15)
# File 07553.json loaded (16)
# File 10245.json loaded (17)
# File 08935.json loaded (18)
# File 07602.json loaded (19)
# File 00981.json loaded (20)
# File 07293.json loaded (21)
# File 08377.json loaded (22)
# File 08450.json loaded (23)
# File 10193.json loaded (24)
# File 03937.json loaded (25)
# File 06832.json loaded (26)
# File 10364.json loaded (27)
# File 05046.json loaded (28)
# File 06268.json loaded (29)
# File 02313.json loaded (30)
# File 04600.json loaded (31)
# File 03075.json loaded (32)
# File 06266.json loaded (33)
# File 05820.json loaded (34)
# File 11118.json loaded (35)
# File 04874.json loaded (36)
# File 08771.json loaded (37)
# File 10194.json loaded (38)
# File 00407.json loaded (39)
# File 03811.json loaded (40)
# File 08657.json loaded (41)
# File 10723.json loaded (42)
# File 03702.json loaded (43)
# File 06595.json loaded (44)
# File 09753.json loaded (45)
# File 05163.json loaded (46)
# File 11196.json loaded (47)
# File 00925.json loaded (48)
# File 07499.json loaded (49)
# File 02636.json loaded (50)
# File 00204.json loaded (51)
# File 09795.json loaded (52)
# File 09065.json loaded (53)
# File 05850.json loaded (54)
# File 06116.json loaded (55)
# File 10004.json loaded (56)
# File 08251.json loaded (57)
# File 10409.json loaded (58)
# File 11441.json loaded (59)
# File 03714.json loaded (60)
# File 05884.json loaded (61)
# File 02053.json loaded (62)
# File 05410.json loaded (63)
# File 03382.json loaded (64)
# File 09521.json loaded (65)
# File 02268.json loaded (66)
# File 00738.json loaded (67)
# File 06109.json loaded (68)
# File 07115.json loaded (69)
# File 07408.json loaded (70)
# File 06117.json loaded (71)
# File 01102.json loaded (72)
# File 00859.json loaded (73)
# File 10052.json loaded (74)
# File 09382.json loaded (75)
# File 06056.json loaded (76)
# File 08862.json loaded (77)
# File 00518.json loaded (78)
# File 07959.json loaded (79)
# File 00058.json loaded (80)
# File 01391.json loaded (81)
# File 03792.json loaded (82)
# File 09809.json loaded (83)
# File 10069.json loaded (84)
# File 06236.json loaded (85)
# File 00991.json loaded (86)
# File 05621.json loaded (87)
# File 02344.json loaded (88)
# File 00178.json loaded (89)
# File 08152.json loaded (90)
# File 10888.json loaded (91)
# File 09589.json loaded (92)
# File 05058.json loaded (93)
# File 10262.json loaded (94)
# File 08817.json loaded (95)
# File 09128.json loaded (96)
# File 07453.json loaded (97)
# File 09147.json loaded (98)
# File 03062.json loaded (99)
# File 04666.json loaded (100)
# File 10376.json loaded (101)
# File 09771.json loaded (102)
# File 08693.json loaded (103)
# File 07048.json loaded (104)
# File 07140.json loaded (105)
# File 04954.json loaded (106)
# File 02941.json loaded (107)
# File 02861.json loaded (108)
# File 09670.json loaded (109)
# File 01201.json loaded (110)
# File 11221.json loaded (111)
# File 05859.json loaded (112)
# File 05447.json loaded (113)
# File 03819.json loaded (114)
# File 07346.json loaded (115)
# File 07207.json loaded (116)
# File 11314.json loaded (117)
# File 00585.json loaded (118)
# File 05264.json loaded (119)
# File 03146.json loaded (120)
# File 01738.json loaded (121)
# File 02597.json loaded (122)
# File 07502.json loaded (123)
# File 06753.json loaded (124)
# File 02495.json loaded (125)
# File 07613.json loaded (126)
# File 06194.json loaded (127)
# File 01772.json loaded (128)
# File 10701.json loaded (129)
# File 09267.json loaded (130)
# File 05574.json loaded (131)
# File 03106.json loaded (132)
# File 02463.json loaded (133)
# File 08203.json loaded (134)
# File 03798.json loaded (135)
# File 05806.json loaded (136)
# File 03615.json loaded (137)
# File 01929.json loaded (138)
# File 09799.json loaded (139)
# File 09973.json loaded (140)
# File 01916.json loaded (141)
# File 00499.json loaded (142)
# File 03908.json loaded (143)
# File 00747.json loaded (144)
# File 00616.json loaded (145)
# File 11044.json loaded (146)
# File 06035.json loaded (147)
# File 09972.json loaded (148)
# File 00978.json loaded (149)
# File 06685.json loaded (150)
# File 00331.json loaded (151)
# File 01437.json loaded (152)
# File 01629.json loaded (153)
# File 11307.json loaded (154)
# File 04636.json loaded (155)
# File 09362.json loaded (156)
# File 06510.json loaded (157)
# File 01173.json loaded (158)
# File 09867.json loaded (159)
# File 06087.json loaded (160)
# File 02024.json loaded (161)
# File 06156.json loaded (162)
# File 00781.json loaded (163)
# File 01048.json loaded (164)
# File 07509.json loaded (165)
# File 08938.json loaded (166)
# File 04509.json loaded (167)
# File 00073.json loaded (168)
# File 00785.json loaded (169)
# File 05938.json loaded (170)
# File 05911.json loaded (171)
# File 01561.json loaded (172)
# File 02288.json loaded (173)
# File 07490.json loaded (174)
# File 05838.json loaded (175)
# File 03685.json loaded (176)
# File 01099.json loaded (177)
# File 07970.json loaded (178)
# File 03663.json loaded (179)
# File 03427.json loaded (180)
# File 02460.json loaded (181)
# File 00570.json loaded (182)
# File 11224.json loaded (183)
# File 06165.json loaded (184)
# File 05020.json loaded (185)
# File 10252.json loaded (186)
# File 10889.json loaded (187)
# File 01869.json loaded (188)
# File 06814.json loaded (189)
# File 09936.json loaded (190)
# File 00749.json loaded (191)
# File 03321.json loaded (192)
# File 02191.json loaded (193)
# File 05867.json loaded (194)
# File 02282.json loaded (195)
# File 04108.json loaded (196)
# File 00578.json loaded (197)
# File 09422.json loaded (198)
# File 04573.json loaded (199)
# File 09539.json loaded (200)
# File 10908.json loaded (201)
# File 07054.json loaded (202)
# File 01463.json loaded (203)
# File 01724.json loaded (204)
# File 08115.json loaded (205)
# File 11322.json loaded (206)
# File 04168.json loaded (207)
# File 01387.json loaded (208)
# File 06708.json loaded (209)
# File 03946.json loaded (210)
# File 00944.json loaded (211)
# File 02898.json loaded (212)
# File 06847.json loaded (213)
# File 00871.json loaded (214)
# File 06736.json loaded (215)
# File 11326.json loaded (216)
# File 10101.json loaded (217)
# File 04127.json loaded (218)
# File 00495.json loaded (219)
# File 07392.json loaded (220)
# File 04628.json loaded (221)
# File 05982.json loaded (222)
# File 04149.json loaded (223)
# File 07551.json loaded (224)
# File 04185.json loaded (225)
# File 08694.json loaded (226)
# File 01439.json loaded (227)
# File 04518.json loaded (228)
# File 07823.json loaded (229)
# File 06511.json loaded (230)
# File 09310.json loaded (231)
# File 07642.json loaded (232)
# File 07653.json loaded (233)
# File 06767.json loaded (234)
# File 06282.json loaded (235)
# File 00946.json loaded (236)
# File 01727.json loaded (237)
# File 08753.json loaded (238)
# File 05361.json loaded (239)
# File 01849.json loaded (240)
# File 11337.json loaded (241)
# File 09708.json loaded (242)
# File 06763.json loaded (243)
# File 01737.json loaded (244)
# File 10031.json loaded (245)
# File 07261.json loaded (246)
# File 07713.json loaded (247)
# File 05969.json loaded (248)
# File 08843.json loaded (249)
# File 08706.json loaded (250)
# File 02555.json loaded (251)
# File 05478.json loaded (252)
# File 08468.json loaded (253)
# File 09643.json loaded (254)
# File 07849.json loaded (255)
# File 04998.json loaded (256)
# File 06815.json loaded (257)
# File 01799.json loaded (258)
# File 01731.json loaded (259)
# File 11075.json loaded (260)
# File 07847.json loaded (261)
# File 05431.json loaded (262)
# File 00872.json loaded (263)
# File 02627.json loaded (264)
# File 01379.json loaded (265)
# File 05721.json loaded (266)
# File 10000.json loaded (267)
# File 07544.json loaded (268)
# File 02768.json loaded (269)
# File 05844.json loaded (270)
# File 11264.json loaded (271)
# File 03265.json loaded (272)
# File 05159.json loaded (273)
# File 00294.json loaded (274)
# File 00510.json loaded (275)
# File 01227.json loaded (276)
# File 00040.json loaded (277)
# File 04970.json loaded (278)
# File 03659.json loaded (279)
# File 02866.json loaded (280)
# File 07277.json loaded (281)
# File 06045.json loaded (282)
# File 10321.json loaded (283)
# File 07754.json loaded (284)
# File 10502.json loaded (285)
# File 07059.json loaded (286)
# File 04430.json loaded (287)
# File 09225.json loaded (288)

# %%
# Объединяем все данные по всем юр. лицам в один DF
egrul_df = pd.concat(dfs, ignore_index=True)
# Out:
# File 04669.json loaded
# File 06439.json loaded
# File 03534.json loaded
# File 00393.json loaded
# File 10339.json loaded
# File 07388.json loaded
# File 09162.json loaded
# File 05575.json loaded
# File 08312.json loaded
# File 06849.json loaded
# File 08667.json loaded
# File 05296.json loaded
# File 10549.json loaded
# File 10851.json loaded
# File 07553.json loaded
# File 03216.json loaded
# File 08935.json loaded
# File 10245.json loaded
# File 07602.json loaded
# File 00981.json loaded
# File 08377.json loaded
# File 07293.json loaded
# File 10193.json loaded
# File 08450.json loaded
# File 06832.json loaded
create table if not exists telecom_companiesokved(
    inn integer,
    ogrn integer,
    kpp integer,
    name text,
    full_name text,
    code_okved text,
    name_okved text,
    type_okved text
)
"""
with sqlite3.connect('hw1.db') as connection:
    cursor = connection.cursor()
    try:
        cursor.execute(create_stmt)
    except(Exception) as error:
        print(error)
        connection.rollback()
    else:
        connection.commit()
    finally:
        cursor.close()

# %%
# Записываем данные из DataFrame в БД
rs = egrul_df.drop(['data'], axis=1)
print(rs)
with sqlite3.connect('hw1.db') as connection:
    rs.to_sql('telecom_companiesokved', connection,
                    if_exists='append',
                    index=False,
                    method='multi')
# Out:
#              ogrn         inn        kpp  \
# 0   1020201686130   257004913   25701001
# 1   1020201257669   242002085   24201001
# 2   1020201993712   266015083   26601001
# 3   1020201775934   261010099   26101001
# 4   1020202000169   266019271   26601001
# 5   1020202000862   266021577   26601001
# 6   1020201848325   263003883   26301001
# 7   1020201932068   265011047   26501001
# 8   1020100695438  0105037128  010501001
# 9   1020100706856  0105038315  057301001
# 10  1020100824743  0106004421  010701001
# 11  1020100699970   105031366  344401001
# 12  1020100704249   105036163   10501001
# 13  1020100705460   105034952   10501001
#
#                                                name  \
# 0                                         ООО "РИК"
# 1                                          ПК "УКВ"
# 2                          ООО " АГЕНТСТВО "СИМПЭК"
# 3                                         ООО "РИО"
# 4                                ООО ИКФ "ИНТЕРКОМ"
# 5                                     ООО "СИСТЕМЫ"
# 6                               ООО "СВЯЗЬ ТРАНЗИТ"
# 7                                      ООО "КОРОНА"
# 8                                     ООО "АЭРОЛУЧ"
# 9     ФКУ ЦИТОВ УФСИН РОССИИ ПО РЕСПУБЛИКЕ ДАГЕСТАН
# 10                                  ООО "ПОТЕНЦИАЛ"
# 11  ФКУ ЦИТОВ УФСИН РОССИИ ПО ВОЛГОГРАДСКОЙ ОБЛАСТИ
# 12                        ООО "КОНТАКТ-СВЯЗЬСИГНАЛ"
# 13                                      ООО "В И С"
#
#                                             full_name code_okved  \
# 0      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РИК"    61.10.9
# 1                   ПРОИЗВОДСТВЕННЫЙ КООПЕРАТИВ "УКВ"      61.10
# 2   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АГЕН...      61.10
# 3      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РИО"    61.10.1
# 4   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ИНЖЕН...      61.10
# 5   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИСТ...    61.10.1
# 6   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СВЯЗ...    61.10.1
# 7   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОРОНА"    61.10.1
# 8   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЭРО...      61.10
# 9   ФЕДЕРАЛЬНОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ "ЦЕНТР ИНЖЕНЕР...    61.10.1
# 10  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПОТЕ...    61.10.1
# 11  ФЕДЕРАЛЬНОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ "ЦЕНТР ИНЖЕНЕР...      61.10
# 12  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОНТ...      61.10
# 13   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "В И С"      61.10
#
#                                            name_okved type_okved
# 0   Деятельность в области связи на базе проводных...        Осн
# 1   Деятельность в области связи на базе проводных...        Осн
# 2   Деятельность в области связи на базе проводных...        Осн
# 3   Деятельность по предоставлению услуг телефонно...        Осн
# 4   Деятельность в области связи на базе проводных...        Осн
# 5   Деятельность по предоставлению услуг телефонно...        Осн
# 6   Деятельность по предоставлению услуг телефонно...        Осн
# 7   Деятельность по предоставлению услуг телефонно...        Осн
# 8   Деятельность в области связи на базе проводных...        Осн
# 9   Деятельность по предоставлению услуг телефонно...        Осн
# 10  Деятельность по предоставлению услуг телефонно...        Осн
# 11  Деятельность в области связи на базе проводных...        Осн
# 12  Деятельность в области связи на базе проводных...        Осн
# 13  Деятельность в области связи на базе проводных...        Осн

# %%
# Проверяем получившийся результат
with sqlite3.connect('hw1.db') as connection:
    df = pd.read_sql('select * from telecom_companiesokved', connection)

display(df)
# Out:
#           inn           ogrn        kpp  \
# 0   257004913  1020201686130   25701001
# 1   242002085  1020201257669   24201001
# 2   266015083  1020201993712   26601001
# 3   261010099  1020201775934   26101001
# 4   266019271  1020202000169   26601001
# 5   266021577  1020202000862   26601001
# 6   263003883  1020201848325   26301001
# 7   265011047  1020201932068   26501001
# 8   105037128  1020100695438   10501001
# 9   105038315  1020100706856   57301001
# 10  106004421  1020100824743   10701001
# 11  105031366  1020100699970  344401001
# 12  105036163  1020100704249   10501001
# 13  105034952  1020100705460   10501001
#
#                                                name  \
# 0                                         ООО "РИК"
# 1                                          ПК "УКВ"
# 2                          ООО " АГЕНТСТВО "СИМПЭК"
# 3                                         ООО "РИО"
# 4                                ООО ИКФ "ИНТЕРКОМ"
# 5                                     ООО "СИСТЕМЫ"
# 6                               ООО "СВЯЗЬ ТРАНЗИТ"
# 7                                      ООО "КОРОНА"
# 8                                     ООО "АЭРОЛУЧ"
# 9     ФКУ ЦИТОВ УФСИН РОССИИ ПО РЕСПУБЛИКЕ ДАГЕСТАН
# 10                                  ООО "ПОТЕНЦИАЛ"
# 11  ФКУ ЦИТОВ УФСИН РОССИИ ПО ВОЛГОГРАДСКОЙ ОБЛАСТИ
# 12                        ООО "КОНТАКТ-СВЯЗЬСИГНАЛ"
# 13                                      ООО "В И С"
#
#                                             full_name code_okved  \
# 0      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РИК"    61.10.9
# 1                   ПРОИЗВОДСТВЕННЫЙ КООПЕРАТИВ "УКВ"      61.10
# 2   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АГЕН...      61.10
# 3      ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РИО"    61.10.1
# 4   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ ИНЖЕН...      61.10
# 5   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СИСТ...    61.10.1
# 6   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СВЯЗ...    61.10.1
# 7   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОРОНА"    61.10.1
# 8   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АЭРО...      61.10
# 9   ФЕДЕРАЛЬНОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ "ЦЕНТР ИНЖЕНЕР...    61.10.1
# 10  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ПОТЕ...    61.10.1
# 11  ФЕДЕРАЛЬНОЕ КАЗЕННОЕ УЧРЕЖДЕНИЕ "ЦЕНТР ИНЖЕНЕР...      61.10
# 12  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОНТ...      61.10
# 13   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "В И С"      61.10
#
#                                            name_okved type_okved
# 0   Деятельность в области связи на базе проводных...        Осн
# 1   Деятельность в области связи на базе проводных...        Осн
# 2   Деятельность в области связи на базе проводных...        Осн
# 3   Деятельность по предоставлению услуг телефонно...        Осн
# 4   Деятельность в области связи на базе проводных...        Осн
# 5   Деятельность по предоставлению услуг телефонно...        Осн
# 6   Деятельность по предоставлению услуг телефонно...        Осн
# 7   Деятельность по предоставлению услуг телефонно...        Осн
# 8   Деятельность в области связи на базе проводных...        Осн
# 9   Деятельность по предоставлению услуг телефонно...        Осн
# 10  Деятельность по предоставлению услуг телефонно...        Осн
# 11  Деятельность в области связи на базе проводных...        Осн
# 12  Деятельность в области связи на базе проводных...        Осн
# 13  Деятельность в области связи на базе проводных...        Осн
