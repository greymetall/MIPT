# %% [markdown]
# ### Домашняя работа № 2
#
# **Цель работы:** научиться использовать Python для загрузки данных
# из интернет с помощью парсинга Web-страниц и через REST API.
#
# В этой работе мы будем загружать данные о вакансиях
# разработчиков Python с сайта hh.ru.
#
# **Задание**
# Разработайте программу на Python, которая скачивает
# информацию о вакансиях разработчиков Python среднего уровня
# (middle python developer).
#
# Программа должна получать следующую информацию о каждой
# вакансии:
# * Название компании.
# * Название позиции (должности).
# * Описание вакансии.
# * Список ключевых навыков.
#
# Программа должна получать данные о вакансиях двумя
# способами:
# 1. Парсинг Web-страниц сайта hh.ru.
# 2. Вызов API hh.ru (https://dev.hh.ru/).
#
# Программа должна скачать информацию о 100 вакансиях.
#
# Скачанные данные о вакансиях запишите в базу данных SQLite, таблица
# vacancies, столбцы:
# * company_name (название компании).
# * position (название позиции).
# * job_description (описание вакансии).
# * key_skills (список ключевых навыков).
#
# **Задание повышенной сложности:** программа должна загружать данные о
# вакансиях асинхронно.
#
# Для сдачи задания пришлите исходные коды программ на Python или
# ссылку на git репозиторий с исходным кодом.

# %% [markdown]
# #### Атрибуты для парсинга
# ##### Основные:
# |Атрибут|Описание|Название атрибута в источнике|
# |:------|:-------|:----------------------------|
# |**company_name**|название компании|employer {name, url, alternate_url}|
# |**position**|название позиции|name|
# |**job_description**|описание вакансии|snippet, description|
# |**key_skills**|список ключевых навыков|key_skills [{name}]|
# ##### Дополнительные:
# |Атрибут|Описание|Название атрибута в источнике|
# |:------|:-------|:----------------------------|
# |area|территория|area {name}|
# |url|основаня ссылка на вакансию
# |alternate_url|альтернативная ссылка на вакансию|
# |published_at|дата публикации вакансии|
# |created_at|дата создания вакансии|
# |archived|признак архивности вакансии|
# |salary|зарплатная вилка|salary {from, to, currency, gross}|
# |responsibility|обязанности|
# |experience|опыт работы|experience {name}|
# |employment|занятость|employment {name}|
# |accredited_it_employer|имеет ли компания аккредитацию IT-компании|
# |professional_roles|профессиональная область|professional_roles {name}|

# %% [markdown]
# ### Решение

# %%
import pandas as pd
# from typing import List
# import requests
from time import sleep
import sqlite3
# from pathlib import Path
import json5
from utils import (areas_parser, get_query, execute, get_data_by_api, get_table,
                   get_view, data_parser, list_to_str, update_table, normalizer)

# %%
settings = json5.load(open('settings.json', encoding='utf-8'))

# globals().update(**settings)
db_name = settings['db_name']
url_areas = settings['url_areas']
url_vac = settings['url_vac']
country = settings['country']
regions = settings['regions']
url_params = settings['url_params']

areas_dct = areas_parser(url_areas, country, regions)  # получаем id заданных регионов
print(f'id регионов: {areas_dct}')
areas_lst = list(areas_dct)

url_params['area'] = areas_lst
# Out:
# id регионов: {1: 'Москва', 2: 'Санкт-Петербург', 1438: 'Краснодарский край'}

# %%
def get_vacancies(url, params, vacancies=None):
    """Получает список вакансий по заданному URL с параметрами"""
    if vacancies is None:
        vacancies = []

    if params.get('page', 0) < params.get('pages', 1):
        data = get_data_by_api(url, params)
        _vacancies = data.get('items', [])
        found, page, pages = data.get('found', 0), data.get('page', 0), data.get('pages', 1)
        params.update(found=found, page=page + 1, pages=pages)
        print(f'\tfound: {found}, pages: {pages}, page: {page} in get_vac')
        vacancies += _vacancies

        print('\tpage after in get_vac', params.get('page'), page)

        # Количество вакансий
        print('Количество спарсенных со стр', page,
              'вакансий по заданным параметрам:', len(_vacancies),
              'всего спарсено вакансий:', len(vacancies), end='\n\n')

        if len(vacancies) < (found if found < 100 else 100) and page < pages:
            sleep(3)
            get_vacancies(url, params, vacancies)
            page += 1
            print('\tpage after recursion in get_vac', params.get('page'), page)

    print('\tpage final in get_vac', params.get('page'))
    return vacancies


def attributes_processing(vacancies_df: pd.DataFrame):
    """Обработка DF вакансий"""
    # Парсим атрибуты, достаём названия у тех, которые имеют форму словарей/списков
    # и добавляем в DF вакансий
    print()
    for attrib in vacancies_df:
        if attrib in ('employer', 'salary'):
            continue
        print('\tParsing attribute', attrib)
        data = vacancies_df[attrib].apply(data_parser)
        if isinstance(data, pd.DataFrame):
            if 'name' in data:
                vacancies_df[attrib] = data['name']
        else:
            vacancies_df[attrib] = data
    print()


def employers_proccessing(vacancies_df: pd.DataFrame):
    # Парсим работодателей в DF для создания отдельной таблицы
    employers_df = vacancies_df.employer.apply(data_parser)
    # Убираем лишний атрибут logo_urls
    employers_df.drop(columns='logo_urls', inplace=True)

    vacancies_df[
        [
            'company_id',
            'company_name',
            'company_trusted'
        ]
    ] = employers_df[
        [
            'id',
            'name',
            'trusted'
        ]
    ]

#     vacancies_df = pd.concat([vacancies_df,
#                               employers_df.add_prefix('company_')],
#                              axis=1)
    # Убираем дубли
    employers_df = employers_df[~employers_df.duplicated()]
    # Запись DF в таблицу БД employers
    update_table('employers', db_name, employers_df)


def key_skills_processing(vacancies_df: pd.DataFrame):
    # Сздаём отдельный DF с ключевыми скиллами
    key_skills_df = vacancies_df[
        ['id', 'key_skills']
    ].rename(
        columns=dict(
            id='vacancy_id',
            key_skills='name'
        )
    )
    # Разбиваем ключевые скиллы, записанные через запятую на списки
    key_skills_df['name'] = key_skills_df.name.apply(lambda x: x.split(',')
                                                     if isinstance(x, str)
                                                     else x)
    # Растягиваем списки на атомарные значения после разбивки
    key_skills_df = key_skills_df.explode('name', ignore_index=True)
    # Нормализуем ключевые слова
    key_skills_df['normalized_name'] = key_skills_df.name.apply(normalizer)

    # Убираем дубли
    key_skills_df = key_skills_df[~key_skills_df.duplicated()]
    # Запись DF в таблицу БД key_skills
    update_table('key_skills', db_name, key_skills_df)


def vacancies_processing(df: pd.DataFrame = pd.DataFrame()):
    """Обработка списка вакансий и преобразование в таблицы"""
    print('page before in proc', url_params.get('page'))
    fill_vac = [{}] * len(df)
    vacancies = get_vacancies(url_vac, url_params, fill_vac)
    found, page, pages = (url_params.get('found', 0),
                          url_params.get('page', 0),
                          url_params.get('pages', 0))
    print('page after in proc', page)
    print('num vac =', len(vacancies))
    print('len df is:', len(df))

    # Парсим список вакансий в DF и оставляем только нужные атрибуты
    vacancy_attribs = ['id', 'name', 'url', 'alternate_url', 'employer', 'area',
                       'employment', 'salary', 'experience', 'professional_roles',
                       'published_at', 'created_at', 'archived']
    global vacancies_df
    vacancies_df = pd.DataFrame(vacancies)[vacancy_attribs]
    # очистка DF от добавленных пустых строк
    vacancies.clear()  # очистка массива со спарсенными ранее вакансиями
    vacancies_df = vacancies_df.dropna(how='all').reset_index(drop=True)
    vacancies_df.rename(columns=dict(name='position'), inplace=True)
    # Убираем архивные вакансии
    vacancies_df = vacancies_df[~vacancies_df.archived.fillna(False)]

    # Обрабатываем атрибуты
    attributes_processing(vacancies_df)

    # Записываем спарсенные компании в таблицу employers
    employers_proccessing(vacancies_df)

    # Парсим зарплаты
    salary_df = vacancies_df.salary.apply(data_parser)
    vacancies_df = pd.concat([vacancies_df,
                              salary_df.add_prefix('salary_')], axis=1)

    # Парсим дополнительные атрибуты по каждой вакансии по API и записываем в DF вакансий
    vacancies_df['details'] = vacancies_df.url.apply(get_data_by_api)

    details_df = vacancies_df.details.apply(data_parser)
    details_df = details_df[
        ['description',
         'key_skills']
    ].rename(
        columns=dict(
            description='job_description'
        )
    )

    vacancies_df = pd.concat([vacancies_df, details_df], axis=1)

    # Обработка атрибута key_skills
    vacancies_df['key_skills'] = vacancies_df.key_skills.apply(list_to_str)
    # Оставляем только те вакансии, в которых указаны ключевые навыки,
    # которые разместили проверенные работодатели,имеющие аккредитацию IT компании
    vacancies_df = vacancies_df[vacancies_df.company_trusted &
                                # vacancies_df.company_accredited_it_employer &
                                vacancies_df.key_skills.notna()]
    # убираем лишние атрибуты
    vacancies_attribs = [
        'id',
        'position',
        'job_description',
        'url',
        'alternate_url',
        'area',
        'employment',
        'experience',
        'professional_roles',
        'key_skills',
        'salary_from',
        'salary_to',
        'salary_currency',
        'salary_gross',
        'company_id',
        'company_name',
        'published_at',
        'created_at',
        'archived'
    ]
    vacancies_df = pd.concat([df, vacancies_df[vacancies_attribs]], ignore_index=True)
    # Убираем дубли
    vacancies_df = vacancies_df[~vacancies_df.id.duplicated()]
    print('len vacancies_df after filters is:', len(vacancies_df))
    if len(vacancies_df) < (found if found < 100 else 100) and page < pages:
        # Если количество вакансий после фильтров оказалось меньше 100,
        # и при этом найдено более 100 вакансий, то запускаем процесс заново
        sleep(10)  # ожидание чтобы не попасть на капчу
        vacancies_processing(vacancies_df.copy(deep=True))
        print('len vacancies_df after recursion is:', len(vacancies_df))
        return
    print('len vacancies_df final is:', len(vacancies_df))

    update_table('vacancies', db_name, vacancies_df)

    # Записываем спарсенные клчевые навыки в таблицу key_skills
    key_skills_processing(vacancies_df)

    # Очистка БД от мусора
    execute('vacuum', db_name)


if __name__ == '__main__':
    # Создаём таблицу employers в БД
    execute(get_query('create_employers.sql'), db_name)
    # Создаём таблицу vacancies в БД
    execute(get_query('create_vacancies.sql'), db_name)
    # Создаём таблицу key_skills в БД
    execute(get_query('create_key_skills.sql'), db_name)

    vacancies_processing()
# Out:
# page before in proc 0
# URL: https://api.hh.ru/vacancies?text=middle+python&search_field=name&page=0&per_page=50&archived=False&area=1&area=2&area=1438
# GET request sucessful
# 	found: 130, pages: 3, page: 0 in get_vac
# 	page after in get_vac 1 0
# Количество спарсенных со стр 0 вакансий по заданным параметрам: 50 всего спарсено вакансий: 50
#
# URL: https://api.hh.ru/vacancies?text=middle+python&search_field=name&page=1&per_page=50&archived=False&area=1&area=2&area=1438&found=130&pages=3
# GET request sucessful
# 	found: 130, pages: 3, page: 1 in get_vac
# 	page after in get_vac 2 1
# Количество спарсенных со стр 1 вакансий по заданным параметрам: 50 всего спарсено вакансий: 100
#
# 	page final in get_vac 2
# 	page after recursion in get_vac 2 1
# 	page final in get_vac 2
# page after in proc 2
# num vac = 100
# len df is: 0
#
# 	Parsing attribute id
# 	Parsing attribute position
# 	Parsing attribute url
# 	Parsing attribute alternate_url
# 	Parsing attribute area
# 	Parsing attribute employment
# 	Parsing attribute experience
# 	Parsing attribute professional_roles
# 	Parsing attribute published_at
# 	Parsing attribute created_at
# 	Parsing attribute archived
#
# Удалено 0 строк(и) из таблицы employers
# Данные записаны в БД в таблицу employers. Записано 84 строк(и)
#
# URL: https://api.hh.ru/vacancies/82841724?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84075135?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83953135?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84135505?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84040721?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82858718?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83800034?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83781440?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82987200?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83756799?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84148906?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83460735?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83225173?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83300859?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84122407?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84149502?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82260854?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/80241657?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82613352?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83333801?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84018020?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84054675?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83948387?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83689584?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83829617?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84057328?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82910400?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83277528?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83279672?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83303987?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83780463?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82830765?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/77731485?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82883031?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83756794?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82942565?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84081902?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83928603?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84064187?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83635129?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81852947?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81585112?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81460227?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83970855?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83781565?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83279670?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83827949?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82778051?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81707961?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83578226?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83808487?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83268235?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83574305?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83279671?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82143529?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83346890?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82834078?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/67115536?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83500026?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83600750?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/76756654?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82890046?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84055816?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83026155?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81123241?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/78634117?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/76756653?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84079995?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83213824?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/71226010?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83153573?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82350625?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83648180?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83387552?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82929739?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83689198?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83026156?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83925674?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82844617?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82986443?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/76868710?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/79584451?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82391131?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83108405?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82170330?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/75726639?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/80935302?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83029207?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82052958?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84112326?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/71226025?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83409678?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81670839?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82105829?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83207801?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/75726638?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82914361?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83111537?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83268142?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82915680?host=hh.ru
# GET request sucessful
# len vacancies_df after filters is: 81
# page before in proc 2
# URL: https://api.hh.ru/vacancies?text=middle+python&search_field=name&page=2&per_page=50&archived=False&area=1&area=2&area=1438&found=130&pages=3
# GET request sucessful
# 	found: 130, pages: 3, page: 2 in get_vac
# 	page after in get_vac 3 2
# Количество спарсенных со стр 2 вакансий по заданным параметрам: 30 всего спарсено вакансий: 111
#
# 	page final in get_vac 3
# page after in proc 3
# num vac = 111
# len df is: 81
#
# 	Parsing attribute id
# 	Parsing attribute position
# 	Parsing attribute url
# 	Parsing attribute alternate_url
# 	Parsing attribute area
# 	Parsing attribute employment
# 	Parsing attribute experience
# 	Parsing attribute professional_roles
# 	Parsing attribute published_at
# 	Parsing attribute created_at
# 	Parsing attribute archived
#
# Удалено 6 строк(и) из таблицы employers
# Данные записаны в БД в таблицу employers. Записано 27 строк(и)
#
# URL: https://api.hh.ru/vacancies/81429521?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83438690?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83734451?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84020130?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83324797?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/79933498?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83126660?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83645238?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82256738?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84072255?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81697936?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/80496136?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83810414?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/78058094?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82194939?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82447169?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/72687504?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83531210?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84062763?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82719353?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81922954?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83110431?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/55088580?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/80496137?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82655283?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82966426?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/84061223?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/82973979?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/81116767?host=hh.ru
# GET request sucessful
# URL: https://api.hh.ru/vacancies/83570495?host=hh.ru
# GET request sucessful
# len vacancies_df after filters is: 106
# len vacancies_df final is: 106
# Удалено 0 строк(и) из таблицы vacancies
# Данные записаны в БД в таблицу vacancies. Записано 106 строк(и)
#
# Удалено 0 строк(и) из таблицы key_skills
# Данные записаны в БД в таблицу key_skills. Записано 800 строк(и)
#
# len vacancies_df after recursion is: 106

# %% [markdown]
# ### Проверка результата

# %%
# Проверяем получившийся результат по компаниям
employers_df = get_table('employers', db_name)
employers_df
# Out:
#             id                                              name  \
# 0    5843588.0                                        Webtronics
# 1    4250943.0                                       hotellab.io
# 2      23314.0                                          НПФ ФИТО
# 3    4960417.0                                            Талала
# 4    3934385.0                                           JetLend
# ..         ...                                               ...
# 100  1102601.0                                    Группа Самолет
# 101  3785152.0                                           Eqvanta
# 102  1144566.0                                         ЛАЙФСТРИМ
# 103   976931.0  The Skolkovo Institute of Science and Technology
# 104  9201947.0                                             Betby
#
#                                      url                   alternate_url  \
# 0    https://api.hh.ru/employers/5843588  https://hh.ru/employer/5843588
# 1    https://api.hh.ru/employers/4250943  https://hh.ru/employer/4250943
# 2      https://api.hh.ru/employers/23314    https://hh.ru/employer/23314
# 3    https://api.hh.ru/employers/4960417  https://hh.ru/employer/4960417
# 4    https://api.hh.ru/employers/3934385  https://hh.ru/employer/3934385
# ..                                   ...                             ...
# 100  https://api.hh.ru/employers/1102601  https://hh.ru/employer/1102601
# 101  https://api.hh.ru/employers/3785152  https://hh.ru/employer/3785152
# 102  https://api.hh.ru/employers/1144566  https://hh.ru/employer/1144566
# 103   https://api.hh.ru/employers/976931   https://hh.ru/employer/976931
# 104  https://api.hh.ru/employers/9201947  https://hh.ru/employer/9201947
#
#                                        vacancies_url  accredited_it_employer  \
# 0    https://api.hh.ru/vacancies?employer_id=5843588                     0.0
# 1    https://api.hh.ru/vacancies?employer_id=4250943                     0.0
# 2      https://api.hh.ru/vacancies?employer_id=23314                     0.0
# 3    https://api.hh.ru/vacancies?employer_id=4960417                     0.0
# 4    https://api.hh.ru/vacancies?employer_id=3934385                     0.0
# ..                                               ...                     ...
# 100  https://api.hh.ru/vacancies?employer_id=1102601                     0.0
# 101  https://api.hh.ru/vacancies?employer_id=3785152                     0.0
# 102  https://api.hh.ru/vacancies?employer_id=1144566                     1.0
# 103   https://api.hh.ru/vacancies?employer_id=976931                     0.0
# 104  https://api.hh.ru/vacancies?employer_id=9201947                     0.0
#
#      trusted
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 100        1
# 101        1
# 102        1
# 103        1
# 104        1
#
# [105 rows x 7 columns]

# %%
# Проверяем получившийся результат по вакансиям
get_table('vacancies', db_name)
# Out:
#            id                                           position  \
# 0    55088580                Разработчик Python (Middle, Senior)
# 1    67115536                 Middle Python разработчик (Django)
# 2    71226010  Middle Python backend developer (ML Space AI C...
# 3    71226025  Middle/Senior Python Developer (Platform Virtu...
# 4    72687504                            Middle Python developer
# ..        ...                                                ...
# 101  84075135      Backend Middle Developer / Python разработчик
# 102  84112326            Разработчик python (Middle/Senior/Lead)
# 103  84122407                            Middle Python Developer
# 104  84148906                            Middle Python Developer
# 105  84149502             Full stack Программист Python (middle)
#
#                                        job_description  \
# 0    <p>NGENIX — лидер на рынке облачных решений и ...
# 1    <p><em>МедРокет</em> — платформа IT-решений дл...
# 2    <p>Приглашаем <strong>Middle Backend Developer...
# 3    <p><strong>Вам предстоит:</strong></p> <ul> <l...
# 4    <p>Мы занимаемся разработкой и поддержкой собс...
# ..                                                 ...
# 101  <p><strong>Международная ĸомпания </strong><st...
# 102  <p>Мы ищем кандидатов для Микрофинансовой комп...
# 103  <p><strong>Кого мы ищем:</strong></p> <p>Сейча...
# 104  <p><strong>S7 TechLab</strong> – IT компания, ...
# 105  <p><strong>Технологический стек проекта: Бекен...
#
#                                                  url  \
# 0    https://api.hh.ru/vacancies/55088580?host=hh.ru
# 1    https://api.hh.ru/vacancies/67115536?host=hh.ru
# 2    https://api.hh.ru/vacancies/71226010?host=hh.ru
# 3    https://api.hh.ru/vacancies/71226025?host=hh.ru
# 4    https://api.hh.ru/vacancies/72687504?host=hh.ru
# ..                                               ...
# 101  https://api.hh.ru/vacancies/84075135?host=hh.ru
# 102  https://api.hh.ru/vacancies/84112326?host=hh.ru
# 103  https://api.hh.ru/vacancies/84122407?host=hh.ru
# 104  https://api.hh.ru/vacancies/84148906?host=hh.ru
# 105  https://api.hh.ru/vacancies/84149502?host=hh.ru
#
#                       alternate_url             area           employment  \
# 0    https://hh.ru/vacancy/55088580           Москва     Полная занятость
# 1    https://hh.ru/vacancy/67115536        Краснодар     Полная занятость
# 2    https://hh.ru/vacancy/71226010           Москва     Полная занятость
# 3    https://hh.ru/vacancy/71226025           Москва     Полная занятость
# 4    https://hh.ru/vacancy/72687504           Москва     Полная занятость
# ..                              ...              ...                  ...
# 101  https://hh.ru/vacancy/84075135           Москва     Полная занятость
# 102  https://hh.ru/vacancy/84112326           Москва     Полная занятость
# 103  https://hh.ru/vacancy/84122407  Санкт-Петербург     Полная занятость
# 104  https://hh.ru/vacancy/84148906           Москва     Полная занятость
# 105  https://hh.ru/vacancy/84149502           Москва  Частичная занятость
#
#              experience        professional_roles  \
# 0         От 3 до 6 лет  Программист, разработчик
# 1    От 1 года до 3 лет  Программист, разработчик
# 2    От 1 года до 3 лет  Программист, разработчик
# 3         От 3 до 6 лет  Программист, разработчик
# 4         От 3 до 6 лет  Программист, разработчик
# ..                  ...                       ...
# 101  От 1 года до 3 лет  Программист, разработчик
# 102         Более 6 лет  Программист, разработчик
# 103       От 3 до 6 лет  Программист, разработчик
# 104  От 1 года до 3 лет  Программист, разработчик
# 105  От 1 года до 3 лет  Программист, разработчик
#
#                                             key_skills  salary_from  \
# 0                Python, PostgreSQL, SQL, MySQL, Scrum          NaN
# 1                             Python, Django Framework     160000.0
# 2    Backend, Middle, Kubernetes, Python, Linux, Go...          NaN
# 3    Python, Linux, SQL, ООП, Английский язык, Kube...          NaN
# 4    Python, Linux, MySQL, Nginx, SQL, PostgreSQL, ...     150000.0
# ..                                                 ...          ...
# 101  Python, Django Framework, PostgreSQL, Redis, Р...          NaN
# 102                                             Python          NaN
# 103  Python, Django Framework, PostgreSQL, GraphQL,...          NaN
# 104                         Python, API, docker, ci/cd          NaN
# 105  Python, Django Framework, Git, Linux, Админист...     100000.0
#
#      salary_to salary_currency  salary_gross  company_id  \
# 0          NaN            None           NaN    656166.0
# 1     240000.0             RUR           1.0   1545815.0
# 2          NaN            None           NaN   3853446.0
# 3          NaN            None           NaN   3853446.0
# 4     200000.0             RUR           0.0   4920624.0
# ..         ...             ...           ...         ...
# 101        NaN            None           NaN   4250943.0
# 102        NaN            None           NaN   4561908.0
# 103        NaN            None           NaN   1829949.0
# 104        NaN            None           NaN    766468.0
# 105   170000.0             RUR           1.0   2869059.0
#
#                           company_name              published_at  \
# 0                               NGENIX  2023-07-26T09:57:45+0300
# 1                             МедРокет  2023-07-24T08:28:25+0300
# 2                             Cloud.ru  2023-06-30T22:38:52+0300
# 3                             Cloud.ru  2023-06-30T22:38:29+0300
# 4                              Селфсек  2023-07-27T19:41:32+0300
# ..                                 ...                       ...
# 101                        hotellab.io  2023-07-26T15:57:41+0300
# 102  Центр развития Среда возможностей  2023-07-27T10:38:42+0300
# 103                               Звук  2023-07-27T11:47:20+0300
# 104                 Группа компаний С7  2023-07-27T14:58:02+0300
# 105                      Гравити Групп  2023-07-27T15:02:32+0300
#
#                    created_at  archived
# 0    2023-07-26T09:57:45+0300         0
# 1    2023-07-24T08:28:25+0300         0
# 2    2023-06-30T22:38:52+0300         0
# 3    2023-06-30T22:38:29+0300         0
# 4    2023-07-27T19:41:32+0300         0
# ..                        ...       ...
# 101  2023-07-26T15:57:41+0300         0
# 102  2023-07-27T10:38:42+0300         0
# 103  2023-07-27T11:47:20+0300         0
# 104  2023-07-27T14:58:02+0300         0
# 105  2023-07-27T15:02:32+0300         0
#
# [106 rows x 19 columns]

# %%
execute('vacuum', db_name)
# Out:
# -1

# %%
# Проверяем получившийся результат по ключевым навыкам
key_skills_df = get_table('key_skills', db_name)
key_skills_df
# Out:
#       id  vacancy_id         name               normalized_name
# 0      1    82841724          Git                           git
# 1      2    82841724        Redis                         redis
# 2      3    82841724   PostgreSQL                           sql
# 3      4    82841724       Python                        python
# 4      5    82841724         REST                      rest api
# ..   ...         ...          ...                           ...
# 795  796    83570495     asinc.io  асинхронное программирование
# 796  797    83570495     fast api                      rest api
# 797  798    83570495     rest api                      rest api
# 798  799    83570495        kafka                         kafka
# 799  800    83570495   Kubernetes                    kubernetes
#
# [800 rows x 4 columns]

# %%
# Проверяем сколько всего вакансий, соответствующих требованиям спарсилось в БД
stmt_total_count = get_query('count_total_vacancies.sql')

get_view(stmt_total_count, db_name)
# Out:
#    cnt_vac
# 0      106

# %% [markdown]
# ### Топ-10 самых востребованных навыков на позицию middle python developer

# %%
# Подсчёт методами Pandas
key_skills_df.normalized_name.value_counts().to_frame('counts').head(10)
# Out:
#           counts
# python       109
# sql          106
# rest api      57
# django        53
# git           39
# docker        36
# linux         33
# redis         20
# rabbitmq      19
# flask         18

# %%
# Топ-10 самых востребованных ключевых навыков на позицию middle_python (запросом)
stmt_top10 = get_query('calculate_top10_key_skills.sql')
get_view(stmt_top10, db_name)
# Out:
#                 normalized_name  counts
# 0                        python     109
# 1                           sql     106
# 2                      rest api      57
# 3                        django      53
# 4                           git      39
# 5                        docker      36
# 6                         linux      33
# 7                         redis      20
# 8                      rabbitmq      19
# 9  асинхронное программирование      18
